# %% [markdown]
# <a href="https://colab.research.google.com/github/Artem04zeb/ml_study/blob/main/regression_calculation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/states.csv")

# %%
df.head()
# Out:
#         state  metro_res  white  hs_grad  poverty  female_house
# 0     Alabama       55.4   71.3     79.9     14.6          14.2
# 1      Alaska       65.6   70.8     90.6      8.3          10.8
# 2     Arizona       88.2   87.7     83.8     13.3          11.1
# 3    Arkansas       52.5   81.0     80.9     18.0          12.1
# 4  California       94.4   77.5     81.1     12.8          12.6

# %%
print('new update')
